# %%
pip install kagglehub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for kagglehub from https://files.pythonhosted.org/packages/49/bf/c2a24567bb6bd80c1fe7cb2ed1a332666476f69c313256aff96094bef93e/kagglehub-0.3.12-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/68.0 kB ? eta -:--:--
#    ---------------------------------------- 68.0/68.0 kB 1.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub
import pandas as pd
import os

# Download the dataset
path = kagglehub.dataset_download("ziya07/blockchain-enabled-6g-microgrid-dataset")

# Print path to dataset files
print("Dataset downloaded to:", path)

# Display contents
for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith(".csv"):
            full_path = os.path.join(root, file)
            print(f"\n📁 Loading CSV: {file}")
            df = pd.read_csv(full_path)
            print(df.head())
        elif file.endswith(".xlsx") or file.endswith(".xls"):
            full_path = os.path.join(root, file)
            print(f"\n📁 Loading Excel: {file}")
            df = pd.read_excel(full_path)
            print(df.head())
# Out:
# Dataset downloaded to: C:\Users\COMPUTECH\.cache\kagglehub\datasets\ziya07\blockchain-enabled-6g-microgrid-dataset\versions\1
#
# 📁 Loading CSV: 6G_Microgridd_Dataset.csv
#              Timestamp  Temperature_C  Humidity_%  Solar_Radiation_Wm2  \
# 0  2023-01-01 00:00:00      21.236204   47.554486           436.276737
# 1  2023-01-01 01:00:00      38.521429   53.140496           399.620887
# 2  2023-01-01 02:00:00      31.959818   79.818318           258.538521
# 3  2023-01-01 03:00:00      27.959755   43.800307           646.540003
# 4  2023-01-01 04:00:00      14.680559   80.875478           528.961744
#
#    Wind_Speed_mps  Energy_Demand_kWh  Residential_Consumption_kWh  \
# 0        7.495054         378.499240                    36.626751
# 1       11.201202         133.030398                    30.935671
# 2        8.440002         205.987862                   128.754551
# 3        1.249539         348.476287                   193.900938
# ...

# %%
import kagglehub
import pandas as pd
import os

# Download dataset
path = kagglehub.dataset_download("ziya07/blockchain-enabled-6g-microgrid-dataset")

# Load CSV/Excel file
for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith(".csv"):
            full_path = os.path.join(root, file)
            df = pd.read_csv(full_path)
            break  # Just load the first file for this example
        elif file.endswith(".xlsx") or file.endswith(".xls"):
            full_path = os.path.join(root, file)
            df = pd.read_excel(full_path)
            break

# Show raw data
print("🔹 Original data:")
print(df.head())

# -----------------------------------------
# 🧹 DATA CLEANING STEPS
# -----------------------------------------

# 1. Show basic info
print("\n🔍 Dataset info:")
df.info()

# 2. Remove columns with mostly missing values (optional)
df = df.dropna(axis=1, thresh=len(df) * 0.5)

# 3. Drop rows with missing values (optional)
df = df.dropna()

# 4. Remove duplicates
df = df.drop_duplicates()

# 5. Strip whitespace from column names
df.columns = df.columns.str.strip()

# 6. Convert data types (example: date columns or numeric)
# df['timestamp'] = pd.to_datetime(df['timestamp'])  # Uncomment if needed

# 7. Remove unwanted columns (example)
# df = df.drop(columns=['UnnecessaryColumn'])  # Replace with actual column names

# 8. Filter out invalid rows (example)
# df = df[df['Voltage'] > 0]  # Example of filtering out bad data

# 9. Reset index
df = df.reset_index(drop=True)

# -----------------------------------------
# ✅ CLEANED DATA
# -----------------------------------------
print("\n✅ Cleaned data:")
print(df.head())

# Optional: save cleaned data to a new file
# df.to_csv("cleaned_dataset.csv", index=False)
# Out:
# 🔹 Original data:
#              Timestamp  Temperature_C  Humidity_%  Solar_Radiation_Wm2  \
# 0  2023-01-01 00:00:00      21.236204   47.554486           436.276737
# 1  2023-01-01 01:00:00      38.521429   53.140496           399.620887
# 2  2023-01-01 02:00:00      31.959818   79.818318           258.538521
# 3  2023-01-01 03:00:00      27.959755   43.800307           646.540003
# 4  2023-01-01 04:00:00      14.680559   80.875478           528.961744
#
#    Wind_Speed_mps  Energy_Demand_kWh  Residential_Consumption_kWh  \
# 0        7.495054         378.499240                    36.626751
# 1       11.201202         133.030398                    30.935671
# 2        8.440002         205.987862                   128.754551
# 3        1.249539         348.476287                   193.900938
# 4        2.783704         266.940205                   110.489836
#
#    Commercial_Consumption_kWh  Industrial_Consumption_kWh  \
# 0                  170.391805                  198.442084
# ...

# %%
pip install matplotlib seaborn plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import os

# STEP 1: Download dataset
path = kagglehub.dataset_download("ziya07/blockchain-enabled-6g-microgrid-dataset")

# STEP 2: Load first CSV or Excel file
df = None
for root, dirs, files in os.walk(path):
    for file in files:
        full_path = os.path.join(root, file)
        if file.endswith(".csv"):
            df = pd.read_csv(full_path)
            break
        elif file.endswith(".xlsx") or file.endswith(".xls"):
            df = pd.read_excel(full_path)
            break

# STEP 3: Check if dataset was loaded
if df is None:
    print("❌ No dataset file found!")
else:
    print("✅ Dataset loaded!")
    print(df.head())




# Compute correlation matrix
corr = df.corr(numeric_only=True)

# Set up the matplotlib figure
plt.figure(figsize=(15, 12))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with better formatting
sns.heatmap(
    corr,
    cmap=cmap,
    annot=True,
    fmt=".2f",
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.75},
    annot_kws={"size": 8}
)

# Rotate axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.yticks(fontsize=9)
plt.title('Correlation Heatmap', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# ✅ Dataset loaded!
#              Timestamp  Temperature_C  Humidity_%  Solar_Radiation_Wm2  \
# 0  2023-01-01 00:00:00      21.236204   47.554486           436.276737
# 1  2023-01-01 01:00:00      38.521429   53.140496           399.620887
# 2  2023-01-01 02:00:00      31.959818   79.818318           258.538521
# 3  2023-01-01 03:00:00      27.959755   43.800307           646.540003
# 4  2023-01-01 04:00:00      14.680559   80.875478           528.961744
#
#    Wind_Speed_mps  Energy_Demand_kWh  Residential_Consumption_kWh  \
# 0        7.495054         378.499240                    36.626751
# 1       11.201202         133.030398                    30.935671
# 2        8.440002         205.987862                   128.754551
# 3        1.249539         348.476287                   193.900938
# 4        2.783704         266.940205                   110.489836
#
#    Commercial_Consumption_kWh  Industrial_Consumption_kWh  \
# 0                  170.391805                  198.442084
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter only numeric columns
numeric_cols = df.select_dtypes(include='number')

# Set up the figure size for clarity
plt.figure(figsize=(18, 10))

# Create a box plot with better formatting
sns.boxplot(data=numeric_cols, palette="Set2")

# Improve x-axis label readability
plt.xticks(rotation=45, ha='right', fontsize=10)

# Add title and layout tweaks
plt.title('Box Plot of Numeric Columns', fontsize=16)
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

plt.show()
